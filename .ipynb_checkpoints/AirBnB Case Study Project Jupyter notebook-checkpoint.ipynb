# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
pd.set_option('display.max_rows', None)    
pd.set_option('display.max_columns', None)
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# How many neighborhood groups are available and which shows up the most?

groups = air_bnb.groupby('neighbourhood_group').count()
print(f'There are total "{len(groups)}" neighbourhood groups')
showsUp_most = groups.idxmax()
print(f'"{showsUp_most["name"]}" is the neighbourhood group which shows up the most.')
# Out:
# There are total "5" neighbourhood groups
# "Manhattan" is the neighbourhood group which shows up the most.

# %%
# Are private rooms the most popular in manhattan?

df_manahattan = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']
total_review s = df_manahattan.groupby(by='room_type')['number_of_reviews'].sum()
total_reviews.loc[['Entire home/apt', 'Private room', 'Shared room']]
# Out:
# room_type
# Entire home/apt    235147
# Private room       209150
# Shared room         10272
# Name: number_of_reviews, dtype: int64

# %%
# Which hosts are the busiest and based on their reviews?

max_per_month = air_bnb['reviews_per_month'].max()
air_bnb[air_bnb['reviews_per_month'] == max_per_month][['host_name']]
# Out:
#       host_name
# 42075   Row NYC

# %%
#Which neighorhood group has the highest average price?

average_price = air_bnb.groupby(by='neighbourhood_group')[['price']].mean()
max_price = average_price['price'].idxmax()
max_price
# Out:
# 'Manhattan'

# %%
# Which neighbor hood group has the highest total price?

air_bnb['total_price'] = air_bnb['price'] * air_bnb['minimum_nights']


# max_groupby = air_bnb.groupby(by='neighbourhood_group')['total_price'].max()
# max_high  = max_groupby.max()

# result = max_groupby[max_groupby == max_high]
# result

air_bnb.groupby(by='neighbourhood_group')['total_price'].max()
maxi= air_bnb['total_price'].idxmax()
highest_total_price = air_bnb.loc[maxi][['neighbourhood_group', 'total_price']]
highest_total_price
# Out:
# neighbourhood_group    Manhattan
# total_price              1170000
# Name: 48043, dtype: object

# %%
# Which top 5 hosts have the highest total price?

sorted_air_bnb = air_bnb.sort_values(by='total_price', ascending = False)
sorted_air_bnb.head()
# Out:
#              id                                          name    host_id  \
# 48043  36056808  Luxury TriBeCa Apartment at an amazing price  271248669
# 9151    7003697           Furnished room in Astoria apartment   20582832
# 12342   9528920           Quiet, Clean, Lit @ LES & Chinatown    3906464
# 17811  13963005                  Gorgeous 2 Bedroom apartment   41870118
# 44429  34221161            Room with sofa bed or air mattress    9295237
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 48043     Jenny           Manhattan          Tribeca  40.71206  -74.00999
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
# 17811     Iveta              Queens     Forest Hills  40.72064  -73.83746
# 44429    Noelle              Queens          Astoria  40.75593  -73.91276
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 48043  Entire home/apt   6500             180                  0         NaN
# 9151      Private room  10000             100                  2  2016-02-13
# 12342     Private room   9999              99                  6  2016-01-01
# 17811  Entire home/apt   2350             365                  0         NaN
# 44429     Private room   2000             365                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 48043                NaN                               1               365
# 9151                0.04                               1                 0
# 12342               0.14                               1                83
# 17811                NaN                               1               364
# 44429                NaN                               2                 0
#
#        total_price
# 48043      1170000
# 9151       1000000
# 12342       989901
# 17811       857750
# 44429       730000

# %%
top_hosts = air_bnb.groupby('host_id')['total_price'].sum().sort_values(ascending=False).head(5)

print("Top 5 hosts with the highest total price:")
print(top_hosts)
# Out:
# Top 5 hosts with the highest total price:
# host_id
# 107434423    2258580
# 271248669    1170000
# 30283594     1164243
# 20582832     1000000
# 3906464       989901
# Name: total_price, dtype: int64

# %%
# Who currently has no (zero) availability with a review count of 100 or more?

zero_available = air_bnb[(air_bnb['availability_365'] == 0) & (air_bnb['number_of_reviews'] >= 100)]
zero_available.head()
# Out:
#         id                                   name  host_id   host_name  \
# 8     5203     Cozy Clean Guest Room - Family Apt     7490   MaryEllen
# 94   20913     Charming 1 bed GR8 WBurg LOCATION!    79402  Christiana
# 132  30031       NYC artists’ loft with roof deck   129352         Sol
# 174  44221         Financial District Luxury Loft   193722       Coral
# 180  45556  Fort Greene, Brooklyn: Center Bedroom    67778        Doug
#
#     neighbourhood_group       neighbourhood  latitude  longitude  \
# 8             Manhattan     Upper West Side  40.80178  -73.96723
# 94             Brooklyn        Williamsburg  40.70984  -73.95775
# 132            Brooklyn          Greenpoint  40.73494  -73.95030
# 174           Manhattan  Financial District  40.70666  -74.01374
# 180            Brooklyn         Fort Greene  40.68863  -73.97691
#
#            room_type  price  minimum_nights  number_of_reviews last_review  \
# 8       Private room     79               2                118  2017-07-21
# 94   Entire home/apt    100               5                168  2018-07-22
# 132     Private room     50               3                193  2019-05-20
# 174  Entire home/apt    196               3                114  2019-06-20
# 180     Private room     65               2                206  2019-06-30
#
#      reviews_per_month  calculated_host_listings_count  availability_365  \
# 8                 0.99                               1                 0
# 94                1.57                               1                 0
# 132               1.86                               1                 0
# 174               1.06                               1                 0
# 180               1.92                               2                 0
#
#      total_price
# 8            158
# 94           500
# 132          150
# 174          588
# 180          130

# %%
zero_available.groupby(by='host_id').first().head()
# Out:
#                id                                   name   host_name  \
# host_id
# 7490         5203     Cozy Clean Guest Room - Family Apt   MaryEllen
# 36897      282443         QT STUDIO FOR ROMANTIC COUPLES       Lydia
# 67778       45556  Fort Greene, Brooklyn: Center Bedroom        Doug
# 79402       20913     Charming 1 bed GR8 WBurg LOCATION!  Christiana
# 116382   11684682              Bright sunny room in NYC!     Anthony
#
#         neighbourhood_group    neighbourhood  latitude  longitude  \
# host_id
# 7490              Manhattan  Upper West Side  40.80178  -73.96723
# 36897             Manhattan        Chinatown  40.71601  -73.99123
# 67778              Brooklyn      Fort Greene  40.68863  -73.97691
# 79402              Brooklyn     Williamsburg  40.70984  -73.95775
# 116382             Brooklyn    Crown Heights  40.67031  -73.94088
#
#                room_type  price  minimum_nights  number_of_reviews  \
# host_id
# 7490        Private room     79               2                118
# 36897    Entire home/apt     90               3                107
# 67778       Private room     65               2                206
# 79402    Entire home/apt    100               5                168
# 116382      Private room     29               2                142
#
#         last_review  reviews_per_month  calculated_host_listings_count  \
# host_id
# 7490     2017-07-21               0.99                               1
# 36897    2019-05-18               1.17                               1
# 67778    2019-06-30               1.92                               2
# 79402    2018-07-22               1.57                               1
# 116382   2019-05-19               3.54                               5
#
#          availability_365  total_price
# host_id
# 7490                    0          158
# 36897                   0          270
# 67778                   0          130
# 79402                   0          500
# 116382                  0           58

# %%
# What host has the highest total of prices and where are they located?

highest_total_of_prices = air_bnb.groupby('host_id')['price'].sum()
host_with_highest_prices = highest_total_of_prices.idxmax()
host_with_highest_prices
with_location = air_bnb.loc[air_bnb['host_id'] == host_with_highest_prices, ['host_id','name', 'neighbourhood', 'neighbourhood_group', 'price']]
with_location
# Out:
#          host_id                                               name  \
# 38293  219517861      Sonder | 180 Water | Incredible 2BR + Rooftop
# 38294  219517861         Sonder | 180 Water | Premier 1BR + Rooftop
# 38588  219517861        Sonder | 180 Water | Charming 1BR + Rooftop
# 39769  219517861            Sonder | The Nash | Artsy 1BR + Rooftop
# 39770  219517861        Sonder | The Nash | Lovely Studio + Rooftop
# 39771  219517861     Sonder | The Nash | Brilliant Studio + Rooftop
# 39772  219517861               Sonder | 11th Ave | Bright 1BR + Gym
# 39773  219517861         Sonder | 11th Ave | Contemporary 1BR + Gym
# 39774  219517861          Sonder | The Nash | Pristine Studio + Gym
# 39775  219517861              Sunny 1BR in Hell's Kitchen by Sonder
# 39776  219517861   Sonder | The Nash | Airy Studio + Fitness Center
# 39777  219517861      Sonder | The Nash | Bohemian Studio + Rooftop
# 39778  219517861            Sonder | The Nash | Simple Studio + Gym
# 39779  219517861             Sonder | The Nash | Creative 1BR + Gym
# 39780  219517861         Sonder | The Nash | Bohemian 1BR + Rooftop
# 39781  219517861          Sonder | The Nash | Charming Studio + Gym
# 39782  219517861      Sonder | The Nash | Polished Studio + Rooftop
# 40476  219517861         Sonder | 180 Water | Chic Studio + Rooftop
# 41362  219517861  Sonder | Stock Exchange | Welcoming 1BR + Sofa...
# 41363  219517861    Sonder | Stock Exchange | Amazing 1BR + Kitchen
# 41364  219517861     Sonder | Wall Street | Quaint Studio + Kitchen
# 41365  219517861  Sonder | Stock Exchange | Peaceful 1BR + Sofa Bed
# 41366  219517861     Sonder | Wall Street | Quaint Studio + Laundry
# 41373  219517861    Sonder | Stock Exchange | Premier 2BR + Laundry
# 45164  219517861            Sonder | 116 John | Lovely Studio + Gym
# 45165  219517861           Sonder | 116 John | Sun-Filled 1BR + Gym
# 45166  219517861              Sonder | 116 John | Relaxed 1BR + Gym
# 45167  219517861         Sonder | 21 Chelsea | Quaint 1BR + Rooftop
# 45168  219517861              Sonder | 116 John | Warm Studio + Gym
# 45342  219517861              Sonder | 116 John | Cozy Studio + Gym
# 45379  219517861             Sonder | 116 John | Dashing 1 BR + Gym
# 45383  219517861           Sonder | 116 John | Vibrant Studio + Gym
# 45386  219517861       Sonder | 116 John | Vibrant Studio + Rooftop
# 45722  219517861                 Sonder | 116 John | Airy 1BR + Gym
# 45723  219517861          Sonder | 116 John | Relaxed 1BR + Rooftop
# 45725  219517861           Sonder | 116 John | Bright 1BR + Rooftop
# 45728  219517861          Sonder | 116 John | Cozy Studio + Rooftop
# 45731  219517861              Sonder | 116 John | Stylish 1BR + Gym
# 45932  219517861             Sonder | 116 John | Sleek Studio + Gym
# 45933  219517861            Sonder | 116 John | Quaint Studio + Gym
# 45934  219517861       Sonder | 116 John | Comfortable Studio + Gym
# 45935  219517861        Sonder | 180 Water | Pleasant 2BR + Rooftop
# 45937  219517861               Airy 1BR in Hell's Kitchen by Sonder
# 45938  219517861               Sonder | 11th Ave | Lovely 1BR + Gym
# 45939  219517861         Sonder | 180 Water | Bold Studio + Rooftop
# 45946  219517861          Exceptional 1BR in Midtown East by Sonder
# 45947  219517861             Charming 1BR in Midtown East by Sonder
# 45948  219517861             Superior 1BR in Midtown East by Sonder
# 45949  219517861  Sonder | Upper East Side | Stylish 1BR + Sofa Bed
# 45950  219517861        Sonder | Upper East Side | Lovely 1BR + Gym
# 45951  219517861          Sonder | The Nash | Playful 1BR + Rooftop
# 45953  219517861             Sonder | The Nash | Bold 1BR + Rooftop
# 45955  219517861    Sonder | The Nash | Vibrant 1BR + Grilling Area
# 45956  219517861        Sonder | 21 Chelsea | Classic 1BR + Rooftop
# 45957  219517861  Sonder | 21 Chelsea | Sophisticated 1BR + Rooftop
# 45958  219517861             Intimate 1BR in Midtown East by Sonder
# 45959  219517861  Sonder | Theater District | Bright 1BR + City ...
# 46021  219517861              Sonder | 116 John | Vibrant 1BR + Gym
# 46214  219517861        Sonder | 116 John | Modern Studio + Rooftop
# 46215  219517861        Sonder | 116 John | Lovely Studio + Rooftop
# 47528  219517861          Sonder | 116 John | Cozy Studio + Laundry
# 47529  219517861             Sonder | 116 John | Tasteful 2BR + Gym
# 47686  219517861              Sonder | 116 John | Classic 1BR + Gym
# 47687  219517861           Sonder | 116 John | Classic Studio + Gym
# 47691  219517861  Sonder | 116 John | Vibrant Studio + Fitness Room
# 47692  219517861     Sonder | 116 John | Vibrant 1BR + Fitness Room
# 47693  219517861         Sonder | 116 John | Stunning 1BR + Rooftop
# 47814  219517861          Sonder | 116 John | Polished Studio + Gym
# 47821  219517861            Sonder | 116 John | Simple Studio + Gym
#
#             neighbourhood neighbourhood_group  price
# 38293  Financial District           Manhattan    302
# 38294  Financial District           Manhattan    229
Danielle_from_Queens = air_bnb[(air_bnb['host_name'] == 'Danielle') & (air_bnb['neighbourhood_group'] == 'Queens')]
Danielle_from_Queens = Danielle_from_Queens.dropna(subset='last_review')
Danielle_from_Queens['last_review'].max()
# Out:
# '2019-07-08'

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
# max_id = air_bnb.groupby(by='host_id').count().idxmax()
# result = air_bnb.loc[max_id][['host_id', 'host_name']]
# result

most_listings_host_id = air_bnb['host_id'].value_counts().idxmax()
most_listings_host_info = air_bnb[air_bnb['host_id'] == most_listings_host_id].copy()

most_listings_host_info['total_number_of_listings'] = most_listings_host_info.shape[0]

most_listings_host_info.head()
# Out:
#              id                                           name    host_id  \
# 38293  30181691  Sonder | 180 Water | Incredible 2BR + Rooftop  219517861
# 38294  30181945     Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708    Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 39769  30937590        Sonder | The Nash | Artsy 1BR + Rooftop  219517861
# 39770  30937591    Sonder | The Nash | Lovely Studio + Rooftop  219517861
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 38293  Sonder (NYC)           Manhattan  Financial District  40.70637
# 38294  Sonder (NYC)           Manhattan  Financial District  40.70771
# 38588  Sonder (NYC)           Manhattan  Financial District  40.70743
# 39769  Sonder (NYC)           Manhattan         Murray Hill  40.74792
# 39770  Sonder (NYC)           Manhattan         Murray Hill  40.74771
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 38293  -74.00645  Entire home/apt    302              29                  0
# 38294  -74.00641  Entire home/apt    229              29                  1
# 38588  -74.00443  Entire home/apt    232              29                  1
# 39769  -73.97614  Entire home/apt    262               2                  8
# 39770  -73.97528  Entire home/apt    255               2                 14
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 38293         NaN                NaN                             327
# 38294  2019-05-29               0.73                             327
# 38588  2019-05-21               0.60                             327
# 39769  2019-06-09               1.86                             327
# 39770  2019-06-10               2.59                             327
#
#        availability_365  total_price  total_number_of_listings
# 38293               309         8758                       327
# 38294               219         6641                       327
# 38588               159         6728                       327
# 39769                91          524                       327
# 39770                81          510                       327

# %%
desired_info = most_listings_host_info[['host_id', 'host_name', 'total_number_of_listings']].head(1)
desired_info
# Out:
#          host_id     host_name  total_number_of_listings
# 38293  219517861  Sonder (NYC)                       327

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
open_availability = len(air_bnb[air_bnb['availability_365'] >= 365])
open_availability
# Out:
# 1295

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
room_type_review = air_bnb.groupby(by='room_type')['number_of_reviews'].sum()
print('Room types with total number of reviews ')
print(room_type_review)


max_reviews_room_type = room_type_review.idxmax()
print(f'Room type with maximum number of reviews: "{max_reviews_room_type}"')
# Out:
# Room types with total number of reviews
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64
# Room type with maximum number of reviews: "Entire home/apt"

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
